# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x0 = np.random.rand(1000) - 0.5
x1 = np.random.rand(1000) - 0.5
X = np.array(list(zip(x0, x1)))
y = np.array([1 if i0 * i1 > 0 else 0 for (i0, i1)  in list(zip(x0, x1))])

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
from knnFeat import knnExtract

# %%
import time
start = time.time()
newX = knnExtract(X, y, k=1, holds = 5)
elapsed_time = time.time() - start
print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
# Out:
# elapsed_time:3.680608034133911[sec]

# %%
plt.scatter(newX[:,0], newX[:,1], c=y)

# %% [markdown]
# # iris dataset

# %%
from sklearn import datasets
iris = datasets.load_iris()
y = iris.target
X = iris.data

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
newX = knnExtract(X, y, k=1, holds = 5)

# %%
plt.scatter(newX[:,0], newX[:,1], c=y)
